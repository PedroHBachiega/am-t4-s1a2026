# %% [markdown]
# # Pipeline | Carregamento e Detecção de Anomalias [Fase 1 - census_data]

# %% [markdown]
# ## Importar dados do Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Bibliotecas de Python

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Carregar Digest de base_census

# %%
import pickle

# %%
with open('/content/drive/MyDrive/am-t4/census.pkl', 'rb') as f:
  X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5146/2310871466.py in <cell line: 0>()
# ----> 1 with open('/content/drive/MyDrive/am-t4/census.pkl', 'rb') as f:
#       2   X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/am-t4/census.pkl'

# %%
X_census_treinamento.shape, Y_census_treinamento.shape

# %%
X_census_teste.shape, Y_census_teste.shape

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naive_census_data = GaussianNB()
naive_census_data.fit(X_credit_treinamento, Y_credit_treinamento)

# %%
GaussianNB()

# %% [markdown]
# ## Criando base previsora

# %%
census_predict = naive_census_data.predict(X_census_teste)

# %%
census_predict

# %%
Y_census_teste

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(Y_census_teste, census_predict)

# %%
confusion_matrix(Y_census_teste, census_predict)

# %%
from yellowbrick.classifier import ConfusionMatrix

# %%
cm_census = ConfusionMatrix(naive_census_data)
cm_census.fit(X_census_treinamento, Y_census_treinamento)
cm_census.score(X_census_teste, Y_census_teste)
